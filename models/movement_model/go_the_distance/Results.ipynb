# %%
import os

from mirrorverse.utils import read_data_w_cache

os.environ['HAVEN_DATABASE'] = 'haven'
os.environ['AWS_PROFILE'] = 'admin'

# %%
TEST = False

table = 'movement_model_inference_m1_a1' if not TEST else 'movement_model_inference_m1_a1_test'
data = read_data_w_cache(
    f'select * from {table}'
)
data = data[data['_selected'].isin([True, False])]
data.head()
# Out:
#    _decision  _choice  _selected  normed_distance  origin_h3_index  \
# 0         14        8      False         0.408450  840c691ffffffff
# 1         14        9      False         0.377435  840c691ffffffff
# 2         14       10      False         0.822227  840c691ffffffff
# 3         14       11      False         0.746331  840c691ffffffff
# 4         14       12      False         0.853178  840c691ffffffff
#
#      next_h3_index         h3_index       time  _individual tag_key  log_odds  \
# 0  840c691ffffffff  840c69bffffffff 2021-03-18           46  210776  4.932559
# 1  840c691ffffffff  840c69dffffffff 2021-03-18           46  210776  5.021342
# 2  840c691ffffffff  840c6b9ffffffff 2021-03-18           46  210776  1.061759
# 3  840c691ffffffff  840c6bbffffffff 2021-03-18           46  210776  1.402260
# 4  840c691ffffffff  840c6d3ffffffff 2021-03-18           46  210776  0.922902
#
#          odds  probability                  experiment_name  \
# 0  138.734146     0.058007  movement-model-experiment-m1-a1
# 1  151.614594     0.063393  movement-model-experiment-m1-a1
# 2    2.891452     0.001209  movement-model-experiment-m1-a1
# 3    4.064376     0.001699  movement-model-experiment-m1-a1
# 4    2.516582     0.001052  movement-model-experiment-m1-a1
#
#                                               run_id  _train  _partition
# 0  c0c9fb46b49fe2652741fb6d3d692ab71b3181d97aef4c...   False           0
# 1  c0c9fb46b49fe2652741fb6d3d692ab71b3181d97aef4c...   False           0
# 2  c0c9fb46b49fe2652741fb6d3d692ab71b3181d97aef4c...   False           0
# 3  c0c9fb46b49fe2652741fb6d3d692ab71b3181d97aef4c...   False           0
# 4  c0c9fb46b49fe2652741fb6d3d692ab71b3181d97aef4c...   False           0

# %%
(
    data[data['_selected']]
    .groupby(['_individual', '_train'])[['probability']]
    .mean().reset_index()
    .groupby('_train')[['probability']].mean()
)
# Out:
#         probability
# _train
# False      0.419904
# True       0.431525
